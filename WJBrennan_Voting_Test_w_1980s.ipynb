# %% [markdown]
# <a href="https://colab.research.google.com/github/litkm/DL-with-DF-Codecademy-/blob/main/WJBrennan_Voting_Test_w_1980s.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Inspiration for this project came from lesson 8 of Prof. Wolfgang Alschner's course, Data Science for Lawyers (https://www.datascienceforlawyers.org/learning-resources/lesson-8/)
#Model adapted from the classification project in unit 4 of Codecademy's skills path, Build Deep Learning Models with TensorFlow

import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from collections import Counter
from sklearn.compose import ColumnTransformer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
from sklearn.metrics import classification_report
from tensorflow.keras.utils import to_categorical
import numpy as np

dataset = 'https://raw.githubusercontent.com/litkm/WJBrennan-Voting/main/WJBrennan_voting.csv'
dataset = pd.read_csv(dataset)

#print(dataset.head())
#print(dataset.describe())
print(dataset.info())

print('Classes and number of values in the dataset',Counter(dataset['vote']))

y = dataset['vote']
x = dataset[['term', 'petitioner', 'respondent', 'jurisdiction', 'caseOrigin', 'caseSource', 'certReason', 'issue', 'issueArea']]

#y = pd.get_dummies(y) #is this necessary or do we process it later?

#X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

Y_train = y.iloc[0:3368]      #Labels for training
Y_test = y.iloc[3367:4745]    #Labels for testing

X_train = x[x['term'] < 1980] #Features for training
X_test = x[x['term'] > 1979]  #Features for testing

columns_for_standard = ['term', 'petitioner', 'respondent', 'jurisdiction', 'caseOrigin', 'caseSource', 'certReason', 'issue', 'issueArea']

ct = ColumnTransformer([('numeric', StandardScaler(), columns_for_standard)])

X_train = ct.fit_transform(X_train) 
X_test = ct.transform(X_test)

le = LabelEncoder()
Y_train = le.fit_transform(Y_train.astype(str))
Y_test = le.transform(Y_test.astype(str))

Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

model = Sequential()
model.add(InputLayer(input_shape=(X_train.shape[1],)))
model.add(Dense(10, activation='relu'))
model.add(Dense(2, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, Y_train, epochs=100, batch_size=8, verbose=1, validation_data=(X_test, Y_test))

loss, acc = model.evaluate(X_test, Y_test, verbose=0)
print("Loss:", loss, "Accuracy:", acc)

y_estimate = model.predict(X_test, verbose=0)
y_estimate = np.argmax(y_estimate, axis=1)
y_true = np.argmax(Y_test, axis=1)
print(classification_report(y_true, y_estimate))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   term          4746 non-null   int64
#  1   petitioner    4746 non-null   int64
#  2   respondent    4746 non-null   int64
#  3   jurisdiction  4746 non-null   int64
#  4   caseOrigin    4746 non-null   int64
#  5   caseSource    4746 non-null   int64
#  6   certReason    4746 non-null   int64
#  7   issue         4746 non-null   int64
#  8   issueArea     4746 non-null   int64
#  9   vote          4746 non-null   object
# dtypes: int64(9), object(1)
# memory usage: 370.9+ KB
# None
# Classes and number of values in the dataset Counter({'majority': 3683, 'dissent': 1063})
# Epoch 1/100
# 421/421 [==============================] - 1s 2ms/step - loss: 0.6399 - accuracy: 0.6876 - val_loss: 0.6360 - val_accuracy: 0.6589
# Epoch 2/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4426 - accuracy: 0.8166 - val_loss: 0.6280 - val_accuracy: 0.6459
# Epoch 3/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4217 - accuracy: 0.8278 - val_loss: 0.6476 - val_accuracy: 0.6154
# Epoch 4/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4223 - accuracy: 0.8168 - val_loss: 0.6438 - val_accuracy: 0.6132
# Epoch 5/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4261 - accuracy: 0.8136 - val_loss: 0.6492 - val_accuracy: 0.6226
# Epoch 6/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4338 - accuracy: 0.8116 - val_loss: 0.6631 - val_accuracy: 0.5914
# Epoch 7/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4120 - accuracy: 0.8207 - val_loss: 0.6775 - val_accuracy: 0.5936
# Epoch 8/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4108 - accuracy: 0.8227 - val_loss: 0.7020 - val_accuracy: 0.5682
# Epoch 9/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4206 - accuracy: 0.8180 - val_loss: 0.6919 - val_accuracy: 0.5668
# Epoch 10/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4090 - accuracy: 0.8238 - val_loss: 0.6819 - val_accuracy: 0.5784
# Epoch 11/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4140 - accuracy: 0.8178 - val_loss: 0.7110 - val_accuracy: 0.5508
# Epoch 12/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4151 - accuracy: 0.8178 - val_loss: 0.6755 - val_accuracy: 0.5972
# Epoch 13/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4278 - accuracy: 0.8110 - val_loss: 0.7218 - val_accuracy: 0.5552
# Epoch 14/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4013 - accuracy: 0.8255 - val_loss: 0.6818 - val_accuracy: 0.5733
# Epoch 15/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4203 - accuracy: 0.8201 - val_loss: 0.7108 - val_accuracy: 0.5552
# Epoch 16/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3983 - accuracy: 0.8213 - val_loss: 0.6896 - val_accuracy: 0.5660
# Epoch 17/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4206 - accuracy: 0.8142 - val_loss: 0.7225 - val_accuracy: 0.5493
# Epoch 18/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3976 - accuracy: 0.8281 - val_loss: 0.7316 - val_accuracy: 0.5261
# Epoch 19/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4241 - accuracy: 0.8067 - val_loss: 0.7531 - val_accuracy: 0.5363
# Epoch 20/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4167 - accuracy: 0.8129 - val_loss: 0.6875 - val_accuracy: 0.5704
# Epoch 21/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3903 - accuracy: 0.8255 - val_loss: 0.7224 - val_accuracy: 0.5414
# Epoch 22/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4064 - accuracy: 0.8203 - val_loss: 0.7113 - val_accuracy: 0.5559
# Epoch 23/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4058 - accuracy: 0.8170 - val_loss: 0.7244 - val_accuracy: 0.5385
# Epoch 24/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3984 - accuracy: 0.8191 - val_loss: 0.7151 - val_accuracy: 0.5435
# Epoch 25/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4064 - accuracy: 0.8195 - val_loss: 0.7070 - val_accuracy: 0.5588
# Epoch 26/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4236 - accuracy: 0.8084 - val_loss: 0.7075 - val_accuracy: 0.5610
# Epoch 27/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4136 - accuracy: 0.8148 - val_loss: 0.7373 - val_accuracy: 0.5327
# Epoch 28/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4168 - accuracy: 0.8145 - val_loss: 0.6924 - val_accuracy: 0.5689
# Epoch 29/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4069 - accuracy: 0.8182 - val_loss: 0.7296 - val_accuracy: 0.5370
# Epoch 30/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3983 - accuracy: 0.8255 - val_loss: 0.7289 - val_accuracy: 0.5493
# Epoch 31/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4017 - accuracy: 0.8166 - val_loss: 0.7974 - val_accuracy: 0.5029
# Epoch 32/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4004 - accuracy: 0.8188 - val_loss: 0.7739 - val_accuracy: 0.5138
# Epoch 33/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4139 - accuracy: 0.8087 - val_loss: 0.7097 - val_accuracy: 0.5610
# Epoch 34/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4105 - accuracy: 0.8191 - val_loss: 0.7063 - val_accuracy: 0.5508
# Epoch 35/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3993 - accuracy: 0.8236 - val_loss: 0.7581 - val_accuracy: 0.5203
# Epoch 36/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4037 - accuracy: 0.8168 - val_loss: 0.6920 - val_accuracy: 0.5675
# Epoch 37/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3943 - accuracy: 0.8308 - val_loss: 0.7703 - val_accuracy: 0.5160
# Epoch 38/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4084 - accuracy: 0.8240 - val_loss: 0.7569 - val_accuracy: 0.5254
# Epoch 39/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4110 - accuracy: 0.8111 - val_loss: 0.6860 - val_accuracy: 0.5747
# Epoch 40/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4304 - accuracy: 0.8089 - val_loss: 0.6883 - val_accuracy: 0.5682
# Epoch 41/100
# 421/421 [==============================] - 1s 2ms/step - loss: 0.3909 - accuracy: 0.8228 - val_loss: 0.7474 - val_accuracy: 0.5203
# Epoch 42/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3957 - accuracy: 0.8347 - val_loss: 0.7304 - val_accuracy: 0.5472
# Epoch 43/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4094 - accuracy: 0.8123 - val_loss: 0.7146 - val_accuracy: 0.5581
# Epoch 44/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4146 - accuracy: 0.8140 - val_loss: 0.6719 - val_accuracy: 0.5864
# Epoch 45/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4182 - accuracy: 0.7980 - val_loss: 0.6501 - val_accuracy: 0.6060
# Epoch 46/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4218 - accuracy: 0.8125 - val_loss: 0.7073 - val_accuracy: 0.5639
# Epoch 47/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4024 - accuracy: 0.8174 - val_loss: 0.7147 - val_accuracy: 0.5472
# Epoch 48/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4114 - accuracy: 0.8128 - val_loss: 0.7437 - val_accuracy: 0.5247
# Epoch 49/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4085 - accuracy: 0.8219 - val_loss: 0.7255 - val_accuracy: 0.5552
# Epoch 50/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4028 - accuracy: 0.8152 - val_loss: 0.7423 - val_accuracy: 0.5472
# Epoch 51/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4235 - accuracy: 0.8070 - val_loss: 0.7133 - val_accuracy: 0.5573
# Epoch 52/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3814 - accuracy: 0.8239 - val_loss: 0.6950 - val_accuracy: 0.5675
# Epoch 53/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4138 - accuracy: 0.8160 - val_loss: 0.7144 - val_accuracy: 0.5443
# Epoch 54/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3962 - accuracy: 0.8223 - val_loss: 0.6835 - val_accuracy: 0.5864
# Epoch 55/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3907 - accuracy: 0.8316 - val_loss: 0.7106 - val_accuracy: 0.5450
# Epoch 56/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4005 - accuracy: 0.8265 - val_loss: 0.7148 - val_accuracy: 0.5653
# Epoch 57/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4010 - accuracy: 0.8266 - val_loss: 0.6611 - val_accuracy: 0.6176
# Epoch 58/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3989 - accuracy: 0.8265 - val_loss: 0.7167 - val_accuracy: 0.5522
# Epoch 59/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4169 - accuracy: 0.8098 - val_loss: 0.6815 - val_accuracy: 0.5972
# Epoch 60/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4060 - accuracy: 0.8199 - val_loss: 0.7098 - val_accuracy: 0.5573
# Epoch 61/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3891 - accuracy: 0.8267 - val_loss: 0.6725 - val_accuracy: 0.5972
# Epoch 62/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4048 - accuracy: 0.8243 - val_loss: 0.6755 - val_accuracy: 0.5951
# Epoch 63/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4002 - accuracy: 0.8237 - val_loss: 0.6660 - val_accuracy: 0.5994
# Epoch 64/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3857 - accuracy: 0.8265 - val_loss: 0.6602 - val_accuracy: 0.5972
# Epoch 65/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4021 - accuracy: 0.8195 - val_loss: 0.6634 - val_accuracy: 0.6118
# Epoch 66/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4032 - accuracy: 0.8255 - val_loss: 0.7335 - val_accuracy: 0.5530
# Epoch 67/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4048 - accuracy: 0.8223 - val_loss: 0.6918 - val_accuracy: 0.5646
# Epoch 68/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3917 - accuracy: 0.8296 - val_loss: 0.6822 - val_accuracy: 0.5856
# Epoch 69/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4073 - accuracy: 0.8197 - val_loss: 0.6650 - val_accuracy: 0.6168
# Epoch 70/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4149 - accuracy: 0.8128 - val_loss: 0.7113 - val_accuracy: 0.5486
# Epoch 71/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3900 - accuracy: 0.8260 - val_loss: 0.7073 - val_accuracy: 0.5602
# Epoch 72/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3950 - accuracy: 0.8203 - val_loss: 0.7139 - val_accuracy: 0.5573
# Epoch 73/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4271 - accuracy: 0.8045 - val_loss: 0.7004 - val_accuracy: 0.5740
# Epoch 74/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3984 - accuracy: 0.8233 - val_loss: 0.6691 - val_accuracy: 0.5936
# Epoch 75/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4069 - accuracy: 0.8155 - val_loss: 0.6957 - val_accuracy: 0.5689
# Epoch 76/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4052 - accuracy: 0.8203 - val_loss: 0.6549 - val_accuracy: 0.6154
# Epoch 77/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3957 - accuracy: 0.8274 - val_loss: 0.6894 - val_accuracy: 0.5697
# Epoch 78/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3982 - accuracy: 0.8249 - val_loss: 0.6496 - val_accuracy: 0.6212
# Epoch 79/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4071 - accuracy: 0.8217 - val_loss: 0.6546 - val_accuracy: 0.6212
# Epoch 80/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4023 - accuracy: 0.8248 - val_loss: 0.6875 - val_accuracy: 0.5871
# Epoch 81/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4025 - accuracy: 0.8203 - val_loss: 0.6964 - val_accuracy: 0.5639
# Epoch 82/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3998 - accuracy: 0.8197 - val_loss: 0.6791 - val_accuracy: 0.5900
# Epoch 83/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4002 - accuracy: 0.8239 - val_loss: 0.6624 - val_accuracy: 0.5994
# Epoch 84/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3982 - accuracy: 0.8206 - val_loss: 0.6576 - val_accuracy: 0.6118
# Epoch 85/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4039 - accuracy: 0.8149 - val_loss: 0.6637 - val_accuracy: 0.6081
# Epoch 86/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4107 - accuracy: 0.8134 - val_loss: 0.6396 - val_accuracy: 0.6263
# Epoch 87/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3926 - accuracy: 0.8277 - val_loss: 0.6649 - val_accuracy: 0.6045
# Epoch 88/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3929 - accuracy: 0.8210 - val_loss: 0.6758 - val_accuracy: 0.5936
# Epoch 89/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3905 - accuracy: 0.8226 - val_loss: 0.6742 - val_accuracy: 0.5893
# Epoch 90/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4123 - accuracy: 0.8096 - val_loss: 0.7013 - val_accuracy: 0.5747
# Epoch 91/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4146 - accuracy: 0.8116 - val_loss: 0.7149 - val_accuracy: 0.5508
# Epoch 92/100
# 421/421 [==============================] - 1s 2ms/step - loss: 0.4020 - accuracy: 0.8222 - val_loss: 0.6722 - val_accuracy: 0.5972
# Epoch 93/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3877 - accuracy: 0.8258 - val_loss: 0.6670 - val_accuracy: 0.6045
# Epoch 94/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4081 - accuracy: 0.8163 - val_loss: 0.6261 - val_accuracy: 0.6560
# Epoch 95/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4125 - accuracy: 0.8172 - val_loss: 0.6878 - val_accuracy: 0.5878
# Epoch 96/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3950 - accuracy: 0.8234 - val_loss: 0.6976 - val_accuracy: 0.5718
# Epoch 97/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3873 - accuracy: 0.8364 - val_loss: 0.6528 - val_accuracy: 0.6110
# Epoch 98/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3891 - accuracy: 0.8337 - val_loss: 0.6515 - val_accuracy: 0.6168
# Epoch 99/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.4053 - accuracy: 0.8210 - val_loss: 0.6717 - val_accuracy: 0.5972
# Epoch 100/100
# 421/421 [==============================] - 1s 1ms/step - loss: 0.3989 - accuracy: 0.8253 - val_loss: 0.6686 - val_accuracy: 0.6030
# Loss: 0.6686424612998962 Accuracy: 0.6030479073524475
#               precision    recall  f1-score   support
#
#            0       0.44      0.76      0.56       459
#            1       0.81      0.52      0.64       919
#
#     accuracy                           0.60      1378
#    macro avg       0.63      0.64      0.60      1378
# weighted avg       0.69      0.60      0.61      1378
